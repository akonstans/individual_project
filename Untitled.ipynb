# %%
import requests
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime, timedelta

# %%
url = 'https://api.polygon.io/v2/aggs/ticker/AAPL/range/1/day/2021-02-13/2023-02-12?adjusted=true&sort=asc&limit=5000&apiKey=yF7xwrr3x9WSu0CebMaupzVrtuBm35RJ'

# %%
response = requests.get(url)

# %%
data = response.json()
data
# Out:
# {'ticker': 'AAPL',
#  'queryCount': 502,
#  'resultsCount': 502,
#  'adjusted': True,
#  'results': [{'v': 80576316.0,
#    'vw': 133.8643,
#    'o': 135.49,
#    'c': 133.19,
#    'h': 136.01,
#    'l': 132.79,
#    't': 1613451600000,
#    'n': 741080},
#   {'v': 97991849.0,
#    'vw': 130.5913,
#    'o': 131.25,
#    'c': 130.84,
#    'h': 132.22,
#    'l': 129.47,
#    't': 1613538000000,
#    'n': 971318},
#   {'v': 96156748.0,
#    'vw': 128.8633,
#    'o': 129.2,
#    'c': 129.71,
#    'h': 129.995,
#    'l': 127.41,
#    't': 1613624400000,
#    'n': 859568},
#   {'v': 87340834.0,
#    'vw': 129.766,
#    'o': 130.24,
#    'c': 129.87,
#    'h': 130.71,
#    'l': 128.8,
#    't': 1613710800000,
#    'n': 683754},
#   {'v': 103295419.0,
#    'vw': 127.0448,
#    'o': 128.01,
#    'c': 126,
#    'h': 129.72,
#    'l': 125.6,
#    't': 1613970000000,
#    'n': 969980},
#   {'v': 158252662.0,
#    'vw': 123.3074,
#    'o': 123.76,
#    'c': 125.86,
#    'h': 126.71,
# ...

# %%
data.keys()
# Out:
# dict_keys(['ticker', 'queryCount', 'resultsCount', 'adjusted', 'results', 'status', 'request_id', 'count'])

# %%
pd.DataFrame(data['results'])
# Out:
#                v        vw        o       c         h        l              t  \
# 0     80576316.0  133.8643  135.490  133.19  136.0100  132.790  1613451600000
# 1     97991849.0  130.5913  131.250  130.84  132.2200  129.470  1613538000000
# 2     96156748.0  128.8633  129.200  129.71  129.9950  127.410  1613624400000
# 3     87340834.0  129.7660  130.240  129.87  130.7100  128.800  1613710800000
# 4    103295419.0  127.0448  128.010  126.00  129.7200  125.600  1613970000000
# ..           ...       ...      ...     ...       ...      ...            ...
# 497   69771906.0  152.0939  152.575  151.73  153.1000  150.780  1675659600000
# 498   83322551.0  153.4202  150.640  154.65  155.2300  150.640  1675746000000
# 499   63620079.0  152.3636  153.880  151.92  154.5800  151.168  1675832400000
# 500   55994243.0  152.2769  153.775  150.87  154.3300  150.420  1675918800000
# 501   57388108.0  150.4054  149.460  151.01  151.3401  149.220  1676005200000
#
#           n
# 0    741080
# ...

# %%
startDate = datetime(2021, 2, 16)
endDate = datetime(2023, 2, 10)

# %%
dates = pd.date_range(startDate,endDate-timedelta(days=1),freq='d')
print(datesRange)
# Out:
# DatetimeIndex(['2021-02-16', '2021-02-17', '2021-02-18', '2021-02-19',
#                '2021-02-20', '2021-02-21', '2021-02-22', '2021-02-23',
#                '2021-02-24', '2021-02-25',
#                ...
#                '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03',
#                '2023-02-04', '2023-02-05', '2023-02-06', '2023-02-07',
#                '2023-02-08', '2023-02-09'],
#               dtype='datetime64[ns]', length=724, freq='D')

# %%
dates[dates.dayofweek < 5]
# Out:
# DatetimeIndex(['2021-02-16', '2021-02-17', '2021-02-18', '2021-02-19',
#                '2021-02-22', '2021-02-23', '2021-02-24', '2021-02-25',
#                '2021-02-26', '2021-03-01',
#                ...
#                '2023-01-27', '2023-01-30', '2023-01-31', '2023-02-01',
#                '2023-02-02', '2023-02-03', '2023-02-06', '2023-02-07',
#                '2023-02-08', '2023-02-09'],
#               dtype='datetime64[ns]', length=518, freq=None)

# %%
dates.drop('2022-01-19')
# Out:
# DatetimeIndex(['2021-02-16', '2021-02-17', '2021-02-18', '2021-02-19',
#                '2021-02-20', '2021-02-21', '2021-02-22', '2021-02-23',
#                '2021-02-24', '2021-02-25',
#                ...
#                '2023-01-31', '2023-02-01', '2023-02-02', '2023-02-03',
#                '2023-02-04', '2023-02-05', '2023-02-06', '2023-02-07',
#                '2023-02-08', '2023-02-09'],
#               dtype='datetime64[ns]', length=723, freq=None)
